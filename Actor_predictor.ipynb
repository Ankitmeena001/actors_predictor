# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('actors_data_modified.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 36 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   name                                     106 non-null    object
#  1   from_south_india                         106 non-null    int64
#  2   is_female                                106 non-null    int64
#  3   is_muslim                                106 non-null    int64
#  4   is_alive                                 106 non-null    int64
#  5   is_married                               106 non-null    int64
#  6   is_comedy_actor                          106 non-null    int64
#  7   is_action_hero                           106 non-null    int64
#  8   is_romantic_hero                         106 non-null    int64
#  9   parents_are_famous                       106 non-null    int64
#  10  is_part_of_golmaal_series                106 non-null    int64
#  11  is_kapoor_as_surname                     106 non-null    int64
#  12  famous_movie_Animal                      106 non-null    int64
#  13  famous_movie_Baaghi Series               106 non-null    int64
#  14  famous_movie_Judwaa Part 1 or 2          106 non-null    int64
#  15  famous_movie_Bhool Bhuliya Part 1 or 2   106 non-null    int64
#  16  famous_movie_Kalki 2898 AD               106 non-null    int64
#  17  famous_movie_Chup Chup Ke                106 non-null    int64
#  18  is_partof_Housefull Series               106 non-null    int64
#  19  famous_movie_Hero No. 1                  106 non-null    int64
#  20  famous_movie_Jai Bhim                    106 non-null    int64
#  21  famous_movie_Krrish 3                    106 non-null    int64
#  22  famous_movie_Judaai                      106 non-null    int64
#  23  famous_movie_Pushpa                      106 non-null    int64
#  24  famous_movie_RRR                         106 non-null    int64
#  25  famous_movie_Stree 1 Or 2                106 non-null    int64
#  26  famous_movie_Student Of The Year 1 Or 2  106 non-null    int64
#  27  is_good_singer                           106 non-null    int64
#  28  is_good_dancer                           106 non-null    int64
#  29  works_in_both_south_and_bollywood        106 non-null    int64
#  30  is_ott_star                              106 non-null    int64
#  31  famous_movie_ludo                        106 non-null    int64
#  32  famous_movie_mirzapur                    106 non-null    int64
#  33  famous_movie_sita_ramam                  106 non-null    int64
#  34  famous_movie_sacred_games                106 non-null    int64
#  35  famous_movie_family_man                  106 non-null    int64
# dtypes: int64(35), object(1)
# memory usage: 29.9+ KB

# %%
X_train = df.iloc[:,1:]
y_train = df['name']

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth = 20)
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(max_depth = 5)
from sklearn.neighbors  import KNeighborsClassifier
knn = KNeighborsClassifier()

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=20)

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=5)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
X_testb = df.sample(n=15)

# %%
X_test = X_testb.iloc[:,1:]
y_test = X_testb['name']

# %%
y_pred_clf = clf.predict(X_test)
y_pred_clf
# Out:
# array(['Rajinikanth', 'Aamir Khan', 'Vijay Deverakonda', 'Aamir Khan',
#        'Alia Bhatt', 'Bhumi Pednekar', 'Dulquer Salmaan',
#        'Pankaj Tripathi', 'Sanjay Dutt', 'Shahid Kapoor', 'Ranveer Singh',
#        'Anushka Sharma', 'Aamir Khan', 'Allu Arjun', 'Johnny Lever'],
#       dtype=object)

# %%
y_test
# Out:
# 40             Rajinikanth
# 90                 Om Puri
# 49       Vijay Deverakonda
# 31    Sushant Singh Rajput
# 54              Alia Bhatt
# 60           Janhvi Kapoor
# 50         Dulquer Salmaan
# 15         Pankaj Tripathi
# 98             Sanjay Dutt
# 35           Shahid Kapoor
# 6            Ranveer Singh
# 66             Yami Gautam
# 16     Nawazuddin Siddiqui
# 44              Allu Arjun
# 80            Johnny Lever
# Name: name, dtype: object

# %%
y_pred_lr = lr.predict(X_test)
y_pred_lr
# Out:
# array(['Rajinikanth', 'Om Puri', 'Vijay Deverakonda',
#        'Sushant Singh Rajput', 'Alia Bhatt', 'Janhvi Kapoor',
#        'Dulquer Salmaan', 'Pankaj Tripathi', 'Sanjay Dutt',
#        'Shahid Kapoor', 'Ranveer Singh', 'Anushka Sharma',
#        'Nawazuddin Siddiqui', 'Allu Arjun', 'Johnny Lever'], dtype=object)

# %%
y_pred_rfc = rfc.predict(X_test)
y_pred_rfc
# Out:
# array(['Rajinikanth', 'Om Puri', 'Vijay Deverakonda', 'Amrish Puri',
#        'Alia Bhatt', 'Janhvi Kapoor', 'Dulquer Salmaan',
#        'Pankaj Tripathi', 'Sanjay Dutt', 'Shahid Kapoor', 'Ranveer Singh',
#        'Anushka Sharma', 'Nawazuddin Siddiqui', 'Allu Arjun',
#        'Johnny Lever'], dtype=object)

# %%
y_pred_knn = knn.predict(X_test)
y_pred_knn
# Out:
# array(['Imran Khan', 'Aditya Roy Kapur', 'Boman Irani', 'Brahmanandam',
#        'Anushka Sharma', 'Arjun Kapoor', 'Emraan Hashmi', 'Kunal Kemmu',
#        'Anupam Kher', 'Boman Irani', 'Ayushmann Khurrana',
#        'Bhumi Pednekar', 'Fahadh Faasil', 'Dhanush', 'Anupam Kher'],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 105 entries, 0 to 105
# Data columns (total 45 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   name                                     105 non-null    object
#  1   from_south_india                         105 non-null    int64
#  2   is_female                                105 non-null    int64
#  3   is_muslim                                105 non-null    int64
#  4   is_alive                                 105 non-null    int64
#  5   is_married                               105 non-null    int64
#  6   is_comedy_actor                          105 non-null    int64
#  7   is_action_hero                           105 non-null    int64
#  8   is_romantic_hero                         105 non-null    int64
#  9   parents_are_famous                       105 non-null    int64
#  10  is_part_of_golmaal_series                105 non-null    int64
#  11  is_kapoor_as_surname                     105 non-null    int64
#  12  famous_movie_Animal                      105 non-null    int64
#  13  famous_movie_Baaghi Series               105 non-null    int64
#  14  famous_movie_Judwaa Part 1 or 2          105 non-null    int64
#  15  famous_movie_Bhool Bhuliya Part 1 or 2   105 non-null    int64
#  16  famous_movie_Kalki 2898 AD               105 non-null    int64
#  17  famous_movie_Chup Chup Ke                105 non-null    int64
#  18  is_partof_Housefull Series               105 non-null    int64
#  19  famous_movie_Hero No. 1                  105 non-null    int64
#  20  famous_movie_Jai Bhim                    105 non-null    int64
#  21  famous_movie_Krrish 3                    105 non-null    int64
#  22  famous_movie_Judaai                      105 non-null    int64
#  23  famous_movie_Pushpa                      105 non-null    int64
#  24  famous_movie_RRR                         105 non-null    int64
#  25  famous_movie_Stree 1 Or 2                105 non-null    int64
#  26  famous_movie_Student Of The Year 1 Or 2  105 non-null    int64
#  27  is_good_singer                           105 non-null    int64
#  28  is_good_dancer                           105 non-null    int64
#  29  works_in_both_south_and_bollywood        105 non-null    int64
#  30  is_ott_star                              105 non-null    int64
#  31  famous_movie_ludo                        105 non-null    int64
#  32  famous_movie_mirzapur                    105 non-null    int64
#  33  famous_movie_sita_ramam                  105 non-null    int64
#  34  famous_movie_sacred_games                105 non-null    int64
#  35  famous_movie_family_man                  105 non-null    int64
#  36  won_miss_india                           105 non-null    int64
#  37  from_Sri Lanka                           105 non-null    int64
#  38  works_in_hollywood                       105 non-null    int64
#  39  age_gratter_then_60                      105 non-null    int64
#  40  husband_is_actor                         105 non-null    int64
#  41  owns_cricket team                        105 non-null    int64
#  42  kissing                                  105 non-null    int64
#  43  wife_is_actoress                         105 non-null    int64
#  44  famous_movie_Gully Boy                   105 non-null    int64
# dtypes: int64(44), object(1)
# memory usage: 37.7+ KB

# %%
user_input = {}

# Ask gender first
ans = input("Is the actor a female? (yes/no): ").strip().lower()
user_input['is_female'] = 1 if ans in ['yes', 'y'] else 0

# Ask common questions
user_input['from_south_india'] = 1 if input("Is the actor from South India? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
user_input['is_alive'] = 1 if input("Is the actor alive? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
user_input['is_married'] = 1 if input("Is the actor married? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
user_input['works_in_hollywood'] = 1 if input("Is the actor works in famous hollywood movies? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
user_input['age_grattter_then_60'] = 1 if input("Is the actor's age is greater then 60? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
user_input['parents_are_famous'] = 1 if input("Is the actor have famous parents ? (yes/no): ").strip().lower() in ['yes', 'y'] else 0

# Conditional questions for male actors
if user_input['is_female'] == 0:
    user_input['is_romantic_hero'] = 1 if input("Is the actor known for romantic roles? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
    if user_input['is_romantic_hero'] == 1:
         user_input['owns_cricket_team'] = 1 if input("Is the actor have a team in ipl? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
    else:
         user_input['is_action_hero'] = 1 if input("Is the actor an action hero? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
         user_input['is_comedy_actor'] = 1 if input("Is the actor known for comedy roles? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
         user_input['is_good_dancer'] = 1 if input("Is the actor a good dancer? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
         user_input['is_good_singer'] = 1 if input("Is the actor a good singer? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
         user_input['is_ott_star'] = 1 if input("Is the actor famous in OTT platforms? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
    if user_input['from_south_india'] == 1:
        user_input['works_in_both_south_and_bollywood'] = 1 if input("Is the actor works in both south and bollywood films? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
        if user_input['is_ott_star'] == 1:
            user_input['famous_movie_Jai Bhim'] = 1 if input("Is the actor starred in Jai Bhim? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
        else:
            user_input['famous_movie_RRR'] = 1 if input("Is the actor starred in RRR? (yes/no): ").strip().lower() in ['yes', 'y'] else 0    
            user_input['famous_movie_Pushpa'] = 1 if input("Is the actor starred in Pushpa? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
            user_input['famous_movie_Kalki 2898 AD'] = 1 if input("Is the actor starred in Kalki 2898 AD? (yes/no): ").strip().lower() in ['yes', 'y'] else 0

    else: 
        if user_input['is_ott_star'] == 1:
            user_input['famous_movie_ludo'] = 1 if input("Is the actor starred in Ludo? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
            user_input['famous_movie_sacred_games'] = 1 if input("Is the actor starred in Sacred Games? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
            user_input['famous_movie_fami_man'] = 1 if input("Is the actor starred in Family Man? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
            user_input['famous_movie_mirzapur'] = 1 if input("Is the actor starred in Mirzapur? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
        else:
            user_input['wife_is_actoress'] = 1 if input("Is the actor's wife is acting in movies? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
            if user_input['wife_is_actoress'] == 1:
                user_input['famous_movie_Gully Boy'] = 1 if input("Is the actor starred in Gully Boy? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
                user_input['famous_movie_Kalki 2898 AD'] = 1 if input("Is the actor starred in Bhool Bhuliya Part 1 or 2? (yes/no): ").strip().lower() in ['yes', 'y'] else 0 
                user_input['is_part_of_golmaal_series'] = 1 if input("Is the actor starred in Golmaal Series? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
                user_input['is_partof_Housfull Series'] = 1 if input("Is the actor starred in Golmaal Series? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
            else:
                user_input['kissing'] = 1 if input("Is the actor known for kissing scenes? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
                user_input['is_part_of_golmaal_series'] = 1 if input("Is the actor starred in Golmaal Series? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
                user_input['is_partof_Housfull Series'] = 1 if input("Is the actor starred in Golmaal Series? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
                user_input['famous_movie_Bhool Bhuliya Part 1 or 2'] = 1 if input("Is the actor starred in Bhool Bhuliya Part 1 or 2? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
                user_input['famous_movie_Judwaa Part 1 or 2'] = 1 if input("Is the actor starred in Judwaa Part 1 or 2? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
                user_input['famous_movie_Chup Chup Ke'] = 1 if input("Is the actor starred in Chup Chup Ke? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
else:
    # For female-specific traits
    user_input['is_ott_star'] = 1 if input("Is the actor famous in OTT platforms? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
    user_input['is_good_dancer'] = 1 if input("Is the actor a good dancer? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
    user_input['is_good_singer'] = 1 if input("Is the actor a good singer? (yes/no): ").strip().lower() in ['yes', 'y'] else 0 
    if user_input['from_south_india'] == 1:
        user_input['works_in_both_south_and_bollywood'] = 1 if input("Is the actor works in both south and bollywood films? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
   
        user_input['famous_movie_Pushpa'] = 1 if input("Is the actor starred in Pushpa? (yes/no): ").strip().lower() in ['yes', 'y'] else 0

    else:
        user_input['won_miss_india'] = 1 if input("Is the actoress won Miss India? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
        user_input['husband_is_actor'] = 1 if input("Is the actoress's husband is actor? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
        user_input['is_part_of_golmaal_series'] = 1 if input("Is the actor starred in Golmaal Series? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
        user_input['is_partof_Housfull Series'] = 1 if input("Is the actor starred in Golmaal Series? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
        user_input['famous_movie_Bhool Bhuliya Part 1 or 2'] = 1 if input("Is the actor starred in Bhool Bhuliya Part 1 or 2? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
        user_input['famous_movie_Judwaa Part 1 or 2'] = 1 if input("Is the actor starred in Judwaa Part 1 or 2? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
        if user_input['famous_movie_Judwaa Part 1 or 2'] == 1:
            user_input['from_Sri Lanka'] = 1 if input("Is the actoress from Sri Lanaka? (yes/no): ").strip().lower() in ['yes', 'y'] else 0
        else:
            user_input['famous_movie_Chup Chup Ke'] = 1 if input("Is the actor starred in Chup Chup Ke? (yes/no): ").strip().lower() in ['yes', 'y'] else 0

# Conditional questions for south actors
    
# Add your random movie questions here as before...
# Fill missing columns with 0
for feature in X_train.columns:
    if feature not in user_input:
        user_input[feature] = 0


# Convert to DataFrame
user_df = pd.DataFrame([user_input])
user_df = user_df[X_train.columns]


# Predict the actor
predicted_actor_index = lr.predict(user_df)[0]
predicted_actor = predicted_actor_index
print("🎬 I think the actor you're thinking of is:", predicted_actor)
# Out:
# Is the actor a female? (yes/no):  n
# Is the actor from South India? (yes/no):  n
# Is the actor alive? (yes/no):  y
# Is the actor married? (yes/no):  y
# Is the actor works in famous hollywood movies? (yes/no):  n
# Is the actor's age is greater then 60? (yes/no):  n
# Is the actor have famous parents ? (yes/no):  n
# Is the actor known for romantic roles? (yes/no):  no
# Is the actor an action hero? (yes/no):  n
# Is the actor known for comedy roles? (yes/no):  n
# Is the actor a good dancer? (yes/no):  y
# Is the actor a good singer? (yes/no):  n
# Is the actor famous in OTT platforms? (yes/no):  n
# Is the actor's wife is acting in movies? (yes/no):  n
# Is the actor known for kissing scenes? (yes/no):  n
# Is the actor starred in Golmaal Series? (yes/no):  n
# Is the actor starred in Golmaal Series? (yes/no):  n
# Is the actor starred in Bhool Bhuliya Part 1 or 2? (yes/no):  n
# Is the actor starred in Judwaa Part 1 or 2? (yes/no):  n
# Is the actor starred in Chup Chup Ke? (yes/no):  y
# 🎬 I think the actor you're thinking of is: Shahid Kapoor

# %%
# List of actors known for good singing
good_singers = [
    "Ayushmann Khurrana",
    "Farhan Akhtar",
    "Parineeti Chopra",
    "Dhanush"
]

# List of actors known for dancing talent
good_dancers = [
    "Hrithik Roshan",
    "Tiger Shroff",
    "Shahid Kapoor",
    "Varun Dhawan",
    "Nora Fatehi",
    "Ranbir Kapoor",
    "Katrina Kaif",
    "Alia Bhatt",
    "Allu Arjun",
    "Tamannaah Bhatia",
    "Ram Charan",
    "Jr NTR",
    "Vijay",
    "Samantha Ruth Prabhu",
    "Sai Pallavi"
]

# Mark singers
df.loc[df["name"].isin(good_singers), "is_good_singer"] = 1

# Mark dancers
df.loc[df["name"].isin(good_dancers), "is_good_dancer"] = 1

# %%
# Define the column names
columns = df.columns.tolist()

# Create a new row with 0s for all columns
new_row = dict.fromkeys(columns, 0)

# Update values for Ananya Pandey
new_row["name"] = "Sai Pallavi"
new_row["from_south_india"] = 1
new_row["is_female"] = 1
new_row["is_alive"] = 1
new_row["is_married"] = 0
new_row["parents_are_famous"] = 0


# Append new row to dataframe
new_row_df = pd.DataFrame([new_row])
df = pd.concat([df, new_row_df], ignore_index=True)

# %%
df.loc[70:,'name']
# Out:
# 70               Huma Qureshi
# 71                 Nayanthara
# 72       Samantha Ruth Prabhu
# 73           Tamannaah Bhatia
# 74        Archana Puran Singh
# 75                Hema Malini
# 76                      Rekha
# 77                    Sridevi
# 78               Brahmanandam
# 79                Amrish Puri
# 80               Johnny Lever
# 81               Paresh Rawal
# 82                 Kader Khan
# 83               Rajpal Yadav
# 84                Boman Irani
# 85                Anupam Kher
# 86             Manoj Bajpayee
# 87             Kareena Kapoor
# 88                Vidya Balan
# 89          Rashmika Mandanna
# 90                    Om Puri
# 91              Ananya Pandey
# 92                Nora Fatehi
# 93              Murnal Thakur
# 94       Jacqueline Fernandez
# 95     Aishwarya Rai Bachchan
# 96       Jacqueline Fernandez
# 97              Fahadh Faasil
# 98                Sanjay Dutt
# 99               Sunil Shetty
# 100              Sonam Kapoor
# 101                     Kajol
# 102              Preity Zinta
# 103             Shakti Kapoor
# 104                R.Madhavan
# 105               Sai Pallavi
# Name: name, dtype: object

# %%
# Add the column with default value 0
# List of popular OTT stars
ott_stars = [
    "Pankaj Tripathi",
    "Manoj Bajpayee",
    "Nawazuddin Siddiqui",
    "Huma Qureshi",
    "Radhika Apte",
    "Abhishek Bachchan",  # Breathe
    "Bobby Deol",
    "Samantha Ruth Prabhu",
    "Suriya",
    "Dhanush"
]

# Update values in column based on name
df.loc[df["name"].isin(ott_stars), "is_ott_star"] = 1

# %%
# Mapping of actors to the movies they have worked in
movie_actor_map = {
    'ludo': ['Pankaj Tripathi', 'Rajkummar Rao', 'Abhishek Bachchan'],
    'mirzapur': ['Pankaj Tripathi'],
    'sita_ramam': ['Dulquer Salmaan','Rashmika Mandanna'],  # optional: cameo or related
    'sacred_games': ['Pankaj Tripathi', 'Nawazuddin Siddiqui'],
    'family_man': ['Manoj Bajpayee', 'Samantha Ruth Prabhu']
}

# Loop through each movie and create a binary column
for movie, actors in movie_actor_map.items():
    col_name = f'famous_movie_{movie}'  # e.g., famous_movie_ludo
    df[col_name] = df['name'].apply(lambda x: 1 if x in actors else 0)

# %%
# Add new column with default value 0
#df['famous_movie_Gully Boy'] = 0

# Mark specific actresses
df.loc[df['name'] == 'Akshay Kumar', 'is_comedy_actor'] = 0
df.loc[df['name'] == 'Rajkummar Rao', 'is_comedy_actor'] = 0

# %%
df['age_gratter_then_60'] = 0
actors_above_55 = [
    # Bollywood Actors
    "Amitabh Bachchan",
    "Anil Kapoor",
    "Jackie Shroff",
    "Sunny Deol",
    "Sanjay Dutt",
    "Boman Irani",
    "Mithun Chakraborty",
    "Paresh Rawal",

    # Bollywood Actresses
    "Hema Malini",
    "Rekha",
    # South Indian Actors
    "Rajinikanth",
    "Kamal Haasan",
    "Chiranjeevi",
    "Nagarjuna"
]
for x in actors_above_55:
    df.loc[df['name'] == x, 'age_gratter_then_60'] = 1

# %%
df.loc[df['is_good_dancer'] == 1,'name']
# Out:
# 5             Ranbir Kapoor
# 7            Hrithik Roshan
# 10             Varun Dhawan
# 11             Tiger Shroff
# 13            Vicky Kaushal
# 35            Shahid Kapoor
# 44               Allu Arjun
# 45               Ram Charan
# 46                   Jr NTR
# 54               Alia Bhatt
# 57             Katrina Kaif
# 72     Samantha Ruth Prabhu
# 73         Tamannaah Bhatia
# 92              Nora Fatehi
# 105             Sai Pallavi
# Name: name, dtype: object

# %%
df.iloc[50:,:]
# Out:
#                        name  from_south_india  is_female  is_muslim  is_alive  \
# 50          Dulquer Salmaan                 1          0          0         1
# 51                     Yash                 1          0          0         1
# 52           Anushka Sharma                 0          1          0         1
# 53         Deepika Padukone                 0          1          0         1
# 54               Alia Bhatt                 0          1          0         1
# 55           Kangana Ranaut                 0          1          0         1
# 56          Priyanka Chopra                 0          1          0         1
# 57             Katrina Kaif                 0          1          0         1
# 58              Kriti Sanon                 0          1          0         1
# 59            Sara Ali Khan                 0          1          0         1
# 60            Janhvi Kapoor                 0          1          0         1
# 61             Kiara Advani                 0          1          0         1
# 62             Disha Patani                 0          1          0         1
# 63           Bhumi Pednekar                 0          1          0         1
# 64            Taapsee Pannu                 0          1          0         1
# 65          Shraddha Kapoor                 0          1          0         1
# 66              Yami Gautam                 0          1          0         1
# 67             Radhika Apte                 0          1          0         1
# 68      Nushrratt Bharuccha                 0          1          0         1
# 69        Rakul Preet Singh                 1          1          0         1
# 70             Huma Qureshi                 0          1          0         1
# 71               Nayanthara                 1          1          0         1
# 72     Samantha Ruth Prabhu                 1          1          0         1
# 73         Tamannaah Bhatia                 1          1          0         1
# 74      Archana Puran Singh                 0          1          0         1
# 75              Hema Malini                 0          1          0         1
# 76                    Rekha                 0          1          0         1
# 77                  Sridevi                 0          1          0         0
# 78             Brahmanandam                 1          0          0         1
# 79              Amrish Puri                 0          0          0         0
# 80             Johnny Lever                 0          0          0         1
# 81             Paresh Rawal                 0          0          0         1
# 82               Kader Khan                 0          0          0         0
# 83             Rajpal Yadav                 0          0          0         1
# 84              Boman Irani                 0          0          0         1
# 85              Anupam Kher                 0          0          0         1
# 86           Manoj Bajpayee                 0          0          0         1
# 87           Kareena Kapoor                 0          1          0         1
# 88              Vidya Balan                 0          1          0         1
# 89        Rashmika Mandanna                 1          1          0         1
# 90                  Om Puri                 0          0          0         0
# 91            Ananya Pandey                 0          1          0         1
# 92              Nora Fatehi                 0          1          0         1
# 93            Murnal Thakur                 1          1          0         1
# 94     Jacqueline Fernandez                 0          1          0         1
# 95   Aishwarya Rai Bachchan                 0          1          0         1
# 97            Fahadh Faasil                 1          0          0         1
# 98              Sanjay Dutt                 0          0          0         1
# 99             Sunil Shetty                 1          0          0         1
# 100            Sonam Kapoor                 0          1          0         1
# 101                   Kajol                 0          1          0         1
# 102            Preity Zinta                 0          1          0         1
# 103           Shakti Kapoor                 0          0          0         1
# 104              R.Madhavan                 1          0          0         1
# 105             Sai Pallavi                 1          1          0         1
#
#      is_married  is_comedy_actor  is_action_hero  is_romantic_hero  \
# 50            1                0               0                 0
# 51            1                0               1                 0
# 52            1                0               0                 0
# 53            1                0               0                 0
# 54            1                0               0                 0
# 55            0                0               0                 0
# 56            1                0               0                 0
# 57            1                0               0                 0
# 58            0                0               0                 0
# 59            0                0               0                 0
# 60            0                0               0                 0
# 61            1                0               0                 0
# 62            0                0               0                 0
# 63            0                0               0                 0
# 64            1                0               0                 0
# 65            0                0               0                 0
# 66            1                0               0                 0
# 67            1                0               0                 0
# 68            0                0               0                 0
# 69            1                0               0                 0
# 70            0                0               0                 0
# 71            1                0               0                 0
# 72            0                0               0                 0
# 73            1                0               0                 0
# 74            1                1               0                 0
# 75            1                0               0                 0
# 76            1                0               0                 0
# 77            1                0               0                 0
# 78            1                1               0                 0
# 79            1                0               0                 0
# 80            1                1               0                 0
# 81            1                1               0                 0
# 82            1                0               0                 0
# 83            1                1               0                 0
# 84            1                0               0                 0
# 85            1                0               0                 0
# 86            1                0               0                 0
# 87            1                0               0                 0
# 88            1                0               0                 0
# 89            0                0               0                 0
# 90            1                0               0                 0
# 91            0                0               0                 0
# 92            0                0               0                 0
# 93            0                0               0                 0
# 94            0                0               0                 0
# 95            1                0               0                 0
# 97            1                0               0                 0
# 98            1                0               0                 0
# 99            1                0               0                 0
# 100           1                0               0                 0
# 101           1                0               0                 0
# 102           1                0               0                 0
# 103           1                0               0                 0
# 104           1                0               0                 0
# 105           0                0               0                 0
#
#      parents_are_famous  ...  famous_movie_family_man  won_miss_india  \
# 50                    1  ...                        0               0
# 51                    0  ...                        0               0
# 52                    0  ...                        0               0
# 53                    0  ...                        0               0
# 54                    1  ...                        0               0
# 55                    0  ...                        0               0
# 56                    0  ...                        0               1
# 57                    0  ...                        0               0
# 58                    0  ...                        0               0
# 59                    1  ...                        0               0
# 60                    1  ...                        0               0
# 61                    0  ...                        0               0
# 62                    0  ...                        0               0
# 63                    0  ...                        0               0
# 64                    0  ...                        0               0
# 65                    1  ...                        0               0
# 66                    0  ...                        0               0
# 67                    0  ...                        0               0
# 68                    0  ...                        0               0
# 69                    0  ...                        0               0
# 70                    0  ...                        0               0
# 71                    0  ...                        0               0
# 72                    0  ...                        1               0
# 73                    0  ...                        0               0
# 74                    0  ...                        0               0
# 75                    0  ...                        0               0
# 76                    0  ...                        0               0
# 77                    0  ...                        0               0
# 78                    0  ...                        0               0
# 79                    0  ...                        0               0
# 80                    0  ...                        0               0
# 81                    0  ...                        0               0
# 82                    0  ...                        0               0
# 83                    0  ...                        0               0
# 84                    0  ...                        0               0
# 85                    0  ...                        0               0
# 86                    0  ...                        1               0
# 87                    0  ...                        0               0
# 88                    0  ...                        0               0
# 89                    0  ...                        0               0
# 90                    0  ...                        0               0
# 91                    1  ...                        0               0
# 92                    0  ...                        0               0
# 93                    0  ...                        0               0
# 94                    0  ...                        0               0
# 95                    0  ...                        0               1
# 97                    0  ...                        0               0
# 98                    1  ...                        0               0
# 99                    0  ...                        0               0
# 100                   1  ...                        0               0
# 101                   1  ...                        0               0
# 102                   0  ...                        0               0
# 103                   0  ...                        0               0
# 104                   0  ...                        0               0
# 105                   0  ...                        0               0
#
#      from_Sri Lanka  works_in_hollywood  age_gratter_then_60  \
# 50                0                   0                    0
# 51                0                   0                    0
# 52                0                   0                    0
# 53                0                   0                    0
# 54                0                   0                    0
# 55                0                   0                    0
# 56                0                   0                    0
# 57                0                   0                    0
# 58                0                   0                    0
# 59                0                   0                    0
# 60                0                   0                    0
# 61                0                   0                    0
# 62                0                   0                    0
# 63                0                   0                    0
# 64                0                   0                    0
# 65                0                   0                    0
# 66                0                   0                    0
# 67                0                   0                    0
# 68                0                   0                    0
# 69                0                   0                    0
# 70                0                   0                    0
# 71                0                   0                    0
# 72                0                   0                    0
# 73                0                   0                    0
# 74                0                   0                    0
# 75                0                   0                    1
# 76                0                   0                    1
# 77                0                   0                    0
# 78                0                   0                    0
# 79                0                   0                    0
# 80                0                   0                    1
# 81                0                   0                    1
# 82                0                   0                    0
# 83                0                   0                    0
# 84                0                   0                    1
# 85                0                   0                    0
# 86                0                   0                    0
# 87                0                   0                    0
# 88                0                   0                    0
# 89                0                   0                    0
# 90                0                   0                    0
# 91                0                   0                    0
# 92                0                   0                    0
# 93                0                   0                    0
# 94                1                   0                    0
# 95                0                   0                    0
# 97                0                   0                    0
# 98                0                   0                    1
# 99                0                   0                    0
# 100               0                   0                    0
# 101               0                   0                    0
# 102               0                   0                    0
# 103               0                   0                    0
# 104               0                   0                    0
# 105               0                   0                    0
#
#      husband_is_actor  owns_cricket team  kissing  wife_is_actoress  \
# 50                  0                  0        0                 0
# 51                  0                  0        0                 0
# 52                  0                  0        0                 0
# 53                  1                  0        0                 0
# 54                  0                  0        0                 0
# 55                  0                  0        0                 0
# 56                  0                  0        0                 0
# 57                  0                  0        0                 0
# 58                  0                  0        0                 0
# 59                  0                  0        0                 0
# 60                  0                  0        0                 0
# 61                  0                  0        0                 0
# 62                  0                  0        0                 0
# 63                  0                  0        0                 0
# 64                  0                  0        0                 0
# 65                  0                  0        0                 0
# 66                  0                  0        0                 0
# 67                  0                  0        0                 0
# 68                  0                  0        0                 0
# 69                  0                  0        0                 0
# 70                  0                  0        0                 0
# 71                  0                  0        0                 0
# 72                  0                  0        0                 0
# 73                  0                  0        0                 0
# 74                  0                  0        0                 0
# 75                  0                  0        0                 0
# 76                  0                  0        0                 0
# 77                  0                  0        0                 0
# 78                  0                  0        0                 0
# 79                  0                  0        0                 0
# 80                  0                  0        0                 0
# 81                  0                  0        0                 0
# 82                  0                  0        0                 0
# 83                  0                  0        0                 0
# 84                  0                  0        0                 0
# 85                  0                  0        0                 0
# 86                  0                  0        0                 0
# 87                  1                  0        0                 0
# 88                  0                  0        0                 0
# 89                  0                  0        0                 0
# 90                  0                  0        0                 0
# 91                  0                  0        0                 0
# 92                  0                  0        0                 0
# 93                  0                  0        0                 0
# 94                  0                  0        0                 0
# 95                  1                  0        0                 0
# 97                  0                  0        0                 0
# 98                  0                  0        0                 0
# 99                  0                  0        0                 0
# 100                 0                  0        0                 0
# 101                 1                  0        0                 0
# 102                 0                  1        0                 0
# 103                 0                  0        0                 0
# 104                 0                  0        0                 0
# 105                 0                  0        0                 0
#
#      famous_movie_Gully Boy
# 50                        0
# 51                        0
# 52                        0
# 53                        0
# 54                        0
# 55                        0
# 56                        0
# 57                        0
# 58                        0
# 59                        0
# 60                        0
# 61                        0
# 62                        0
# 63                        0
# 64                        0
# 65                        0
# 66                        0
# 67                        0
# 68                        0
# 69                        0
# 70                        0
# 71                        0
# 72                        0
# 73                        0
# 74                        0
# 75                        0
# 76                        0
# 77                        0
# 78                        0
# 79                        0
# 80                        0
# 81                        0
# 82                        0
# 83                        0
# 84                        0
# 85                        0
# 86                        0
# 87                        0
# 88                        0
# 89                        0
# 90                        0
# 91                        0
# 92                        0
# 93                        0
# 94                        0
# 95                        0
# 97                        0
# 98                        0
# 99                        0
# 100                       0
# 101                       0
# 102                       0
# 103                       0
# 104                       0
# 105                       0
#
# [55 rows x 45 columns]

# %%
df=df.drop(index=96,axis=0)

# %%
import joblib

# Assuming your trained model is called lr, and your training data is X_train
joblib.dump(lr, "lr.pkl")
joblib.dump(X_train.columns.tolist(), "X_train_columns.pkl")
# Out:
# ['X_train_columns.pkl']

# %%
import streamlit as st
import pandas as pd
import joblib

# Load the trained model and training columns
lr = joblib.load("lr.pkl")
X_train = joblib.load("X_train_columns.pkl")  # This should be a list of feature names

st.title("🎭 Indian Actor Akinator")
st.write("Answer a few questions, and I'll try to guess the actor you're thinking of!")

user_input = {}

# Gender
is_female = st.radio("Is the actor a female?", ["Yes", "No"]) == "Yes"
user_input['is_female'] = 1 if is_female else 0

# Common Questions
user_input['from_south_india'] = 1 if st.radio("Is the actor from South India?", ["Yes", "No"]) == "Yes" else 0
user_input['is_alive'] = 1 if st.radio("Is the actor alive?", ["Yes", "No"]) == "Yes" else 0
user_input['is_married'] = 1 if st.radio("Is the actor married?", ["Yes", "No"]) == "Yes" else 0
user_input['works_in_hollywood'] = 1 if st.radio("Has the actor worked in Hollywood movies?", ["Yes", "No"]) == "Yes" else 0
user_input['age_grattter_then_60'] = 1 if st.radio("Is the actor older than 60?", ["Yes", "No"]) == "Yes" else 0
user_input['parents_are_famous'] = 1 if st.radio("Are the actor's parents famous?", ["Yes", "No"]) == "Yes" else 0

if not is_female:
    user_input['is_romantic_hero'] = 1 if st.radio("Is the actor known for romantic roles?", ["Yes", "No"]) == "Yes" else 0
    if user_input['is_romantic_hero']:
        user_input['owns_cricket_team'] = 1 if st.radio("Does the actor own an IPL team?", ["Yes", "No"]) == "Yes" else 0
    else:
        user_input['is_action_hero'] = 1 if st.radio("Is the actor an action hero?", ["Yes", "No"]) == "Yes" else 0
        user_input['is_comedy_actor'] = 1 if st.radio("Is the actor known for comedy roles?", ["Yes", "No"]) == "Yes" else 0
        user_input['is_good_dancer'] = 1 if st.radio("Is the actor a good dancer?", ["Yes", "No"]) == "Yes" else 0
        user_input['is_good_singer'] = 1 if st.radio("Is the actor a good singer?", ["Yes", "No"]) == "Yes" else 0
        user_input['is_ott_star'] = 1 if st.radio("Is the actor famous on OTT platforms?", ["Yes", "No"]) == "Yes" else 0
    
    if user_input['from_south_india']:
        user_input['works_in_both_south_and_bollywood'] = 1 if st.radio("Works in both South and Bollywood?", ["Yes", "No"]) == "Yes" else 0
        if user_input.get('is_ott_star', 0):
            user_input['famous_movie_Jai Bhim'] = 1 if st.radio("Starred in Jai Bhim?", ["Yes", "No"]) == "Yes" else 0
        else:
            user_input['famous_movie_RRR'] = 1 if st.radio("Starred in RRR?", ["Yes", "No"]) == "Yes" else 0
            user_input['famous_movie_Pushpa'] = 1 if st.radio("Starred in Pushpa?", ["Yes", "No"]) == "Yes" else 0
            user_input['famous_movie_Kalki 2898 AD'] = 1 if st.radio("Starred in Kalki 2898 AD?", ["Yes", "No"]) == "Yes" else 0
    else:
        if user_input.get('is_ott_star', 0):
            user_input['famous_movie_ludo'] = 1 if st.radio("Starred in Ludo?", ["Yes", "No"]) == "Yes" else 0
            user_input['famous_movie_sacred_games'] = 1 if st.radio("Starred in Sacred Games?", ["Yes", "No"]) == "Yes" else 0
            user_input['famous_movie_fami_man'] = 1 if st.radio("Starred in Family Man?", ["Yes", "No"]) == "Yes" else 0
            user_input['famous_movie_mirzapur'] = 1 if st.radio("Starred in Mirzapur?", ["Yes", "No"]) == "Yes" else 0
        else:
            user_input['wife_is_actoress'] = 1 if st.radio("Is his wife an actress?", ["Yes", "No"]) == "Yes" else 0
            if user_input['wife_is_actoress']:
                user_input['famous_movie_Gully Boy'] = 1 if st.radio("Starred in Gully Boy?", ["Yes", "No"]) == "Yes" else 0
                user_input['famous_movie_Kalki 2898 AD'] = 1 if st.radio("Starred in Bhool Bhulaiyaa 1 or 2?", ["Yes", "No"]) == "Yes" else 0
                user_input['is_part_of_golmaal_series'] = 1 if st.radio("Starred in Golmaal series?", ["Yes", "No"]) == "Yes" else 0
                user_input['is_partof_Housfull Series'] = 1 if st.radio("Starred in Housefull series?", ["Yes", "No"]) == "Yes" else 0
            else:
                user_input['kissing'] = 1 if st.radio("Known for kissing scenes?", ["Yes", "No"]) == "Yes" else 0
                user_input['is_part_of_golmaal_series'] = 1 if st.radio("Starred in Golmaal series?", ["Yes", "No"]) == "Yes" else 0
                user_input['is_partof_Housfull Series'] = 1 if st.radio("Starred in Housefull series?", ["Yes", "No"]) == "Yes" else 0
                user_input['famous_movie_Bhool Bhuliya Part 1 or 2'] = 1 if st.radio("Starred in Bhool Bhulaiyaa 1 or 2?", ["Yes", "No"]) == "Yes" else 0
                user_input['famous_movie_Judwaa Part 1 or 2'] = 1 if st.radio("Starred in Judwaa 1 or 2?", ["Yes", "No"]) == "Yes" else 0
                user_input['famous_movie_Chup Chup Ke'] = 1 if st.radio("Starred in Chup Chup Ke?", ["Yes", "No"]) == "Yes" else 0
else:
    user_input['is_ott_star'] = 1 if st.radio("Is the actress famous on OTT?", ["Yes", "No"]) == "Yes" else 0
    user_input['is_good_dancer'] = 1 if st.radio("Is she a good dancer?", ["Yes", "No"]) == "Yes" else 0
    user_input['is_good_singer'] = 1 if st.radio("Is she a good singer?", ["Yes", "No"]) == "Yes" else 0
    if user_input['from_south_india']:
        user_input['works_in_both_south_and_bollywood'] = 1 if st.radio("Works in both South and Bollywood?", ["Yes", "No"]) == "Yes" else 0
        user_input['famous_movie_Pushpa'] = 1 if st.radio("Starred in Pushpa?", ["Yes", "No"]) == "Yes" else 0
    else:
        user_input['won_miss_india'] = 1 if st.radio("Won Miss India?", ["Yes", "No"]) == "Yes" else 0
        user_input['husband_is_actor'] = 1 if st.radio("Husband is an actor?", ["Yes", "No"]) == "Yes" else 0
        user_input['is_part_of_golmaal_series'] = 1 if st.radio("Starred in Golmaal series?", ["Yes", "No"]) == "Yes" else 0
        user_input['is_partof_Housfull Series'] = 1 if st.radio("Starred in Housefull series?", ["Yes", "No"]) == "Yes" else 0
        user_input['famous_movie_Bhool Bhuliya Part 1 or 2'] = 1 if st.radio("Starred in Bhool Bhulaiyaa 1 or 2?", ["Yes", "No"]) == "Yes" else 0
        user_input['famous_movie_Judwaa Part 1 or 2'] = 1 if st.radio("Starred in Judwaa 1 or 2?", ["Yes", "No"]) == "Yes" else 0
        if user_input['famous_movie_Judwaa Part 1 or 2']:
            user_input['from_Sri Lanka'] = 1 if st.radio("Is the actress from Sri Lanka?", ["Yes", "No"]) == "Yes" else 0
        else:
            user_input['famous_movie_Chup Chup Ke'] = 1 if st.radio("Starred in Chup Chup Ke?", ["Yes", "No"]) == "Yes" else 0

# Fill missing features with 0
for feature in X_train:
    if feature not in user_input:
        user_input[feature] = 0

user_df = pd.DataFrame([user_input])[X_train]

# Predict
predicted_actor_index = lr.predict(user_df)[0]
st.success(f"🎬 I think the actor you're thinking of is: **{predicted_actor_index}**")
# Out:
# 2025-07-22 10:21:22.337
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\ankit\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-07-22 10:21:22.341 Session state does not function when running a script without `streamlit run`
# DeltaGenerator()
